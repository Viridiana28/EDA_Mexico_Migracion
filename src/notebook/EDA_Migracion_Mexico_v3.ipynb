# %% [markdown]
# ![image_2.png](./img/image_2.png)

# %% [markdown]
# ## Summary
#
# * #### [Introducción](#introduccion)
# * #### [Hipotesis](#hipotesis)
# * #### [Procedimiento](#procedimiento)
#     * #### [Extracción](#extraccion)
#     * #### [Limpieza de datos (paso 1)](#limpieza)
#     * #### [Unificación de datos](#unificacion)
#     * #### [Limpieza de datos (paso 2)](#limpieza2)
# * #### [Inicio del análisis](#analisis)

# %% [markdown]
# # **Análisis exploratorio de Datos (EDA)**
#
# ### Introduccion <a id="introduccion"></a>
#
# ## México y la migración ¿Cuáles son sus causas?
#
# ¿Depende de la causa de migración la razón por la cuál un mexicano migra a los Estados Unidos Américanos o a otros países?
#
# **Hipótesis a contrastar**: Se asume que la causa de migración determina las razones por la cuales los mexicanos migran a los Estados Unidos Américanos u a otros países. <a id="hipotesis"></a>

# %% [markdown]
# ### Procedimiento <a id="procedimiento"></a>
#
# Como primer paso se importan las librerias que se necesitarán para poder realizar el anális exploratorio de datos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import plotly.express as px
import os.path 
import sqlite3

# %% [markdown]
# En esta sección leeremos los archivos que necesitaremos para hacer tal análisis
#
# >En esta parte nos enfrentamoss a dificultades para poder acceder al archivo puesto que nos marca un error diciendo que el archivo no se puede encontrar,
# por lo tanto se ha revisado en stack overflow y encontrado una solución que ha funcionado con agreagr la letra r al incio
# >> El siguiente reto al que nos encontramos es que el archivo en excel esta bloqueado, así que no podemos ajustar desde el excel directamente, por lo que tendrémos que renombrar las columnas usando métodos de pandas

# %% [markdown]
# ### Extracción de datos <a id="extraccion"></a>

# %%
df_INEGI_Yr2020_07 = pd.read_excel(r"/Users/stefa/REPO_PRUEBA/EDA_Proyecto/src/data/cpv2020.xlsx",sheet_name="07",skiprows=[0,1,2,3,4,5]) #se utiliza letra r para leer el archivo
df_INEGI_Yr2020_07.head(5)
# Out:
#                            Unnamed: 0                Unnamed: 1 Unnamed: 2  \
# 0                                 NaN                       NaN        NaN
# 1       Estados Unidos MexicanosTotal  Estados Unidos Mexicanos      Total
# 2  Estados Unidos Mexicanos05-09 años  Estados Unidos Mexicanos      Total
# 3  Estados Unidos Mexicanos10-14 años  Estados Unidos Mexicanos      Total
# 4  Estados Unidos Mexicanos15-19 años  Estados Unidos Mexicanos      Total
#
#    Unnamed: 3  Unnamed: 4  Buscar trabajo  Cambio u oferta de trabajo  \
# 0         NaN         NaN             NaN                         NaN
# 1       Total   6888490.0       1129177.0                    855435.0
# 2  05-09 años    624339.0             0.0                         0.0
# 3  10-14 años    542634.0          6758.0                      7067.0
# 4  15-19 años    595630.0         73319.0                     22189.0
#
#    Reunirse con la familia  Se casó o unió  Estudiar  \
# 0                      NaN             NaN       NaN
# 1                2515611.0        636148.0  463170.0
# 2                 479214.0             0.0   42379.0
# 3                 385222.0          1102.0   58274.0
# 4                 270949.0         41917.0  117612.0
#
#    Por inseguridad delictiva o violencia  Por desastres naturales  \
# 0                                    NaN                      NaN
# 1                               274158.0                  24742.0
# 2                                24816.0                   1760.0
# 3                                26181.0                   1826.0
# 4                                23439.0                   1543.0
#
#    Lo deportaron  Otra causa  No especificado
# 0            NaN         NaN              NaN
# 1        41390.0    860165.0          88494.0
# 2          587.0     67922.0           7661.0
# 3          630.0     50036.0           5538.0
# 4          482.0     37946.0           6234.0

# %% [markdown]
# >En esta parte nos encontramos un nuevo reto ya que las filas con los títulos estaban concatenadas, así que parecía que necesitaba poner un salto de carro, al final
# buscando en las librerías y Stack overflow he visto que con el inplace funcionaba el cambio de nombre

# %%
df_INEGI_Yr2020_07.rename(columns ={"Unnamed: 0": "Unicode", "Unnamed: 1":"Entidad Federativa de residencia actual","Unnamed: 2":"Género","Unnamed: 3": "Grupos quinquenales de edad","Unnamed: 4" : "Población de 5 años y más migrante"},inplace=True)
df_INEGI_Yr2020_07.head(5) #Cuando se imprime se puede notar que las columnas están renombradas
# Out:
#                               Unicode Entidad Federativa de residencia actual  \
# 0                                 NaN                                     NaN
# 1       Estados Unidos MexicanosTotal                Estados Unidos Mexicanos
# 2  Estados Unidos Mexicanos05-09 años                Estados Unidos Mexicanos
# 3  Estados Unidos Mexicanos10-14 años                Estados Unidos Mexicanos
# 4  Estados Unidos Mexicanos15-19 años                Estados Unidos Mexicanos
#
#   Género Grupos quinquenales de edad  Población de 5 años y más migrante  \
# 0    NaN                         NaN                                 NaN
# 1  Total                       Total                           6888490.0
# 2  Total                  05-09 años                            624339.0
# 3  Total                  10-14 años                            542634.0
# 4  Total                  15-19 años                            595630.0
#
#    Buscar trabajo  Cambio u oferta de trabajo  Reunirse con la familia  \
# 0             NaN                         NaN                      NaN
# 1       1129177.0                    855435.0                2515611.0
# 2             0.0                         0.0                 479214.0
# 3          6758.0                      7067.0                 385222.0
# 4         73319.0                     22189.0                 270949.0
#
#    Se casó o unió  Estudiar  Por inseguridad delictiva o violencia  \
# 0             NaN       NaN                                    NaN
# 1        636148.0  463170.0                               274158.0
# 2             0.0   42379.0                                24816.0
# 3          1102.0   58274.0                                26181.0
# 4         41917.0  117612.0                                23439.0
#
#    Por desastres naturales  Lo deportaron  Otra causa  No especificado
# 0                      NaN            NaN         NaN              NaN
# 1                  24742.0        41390.0    860165.0          88494.0
# 2                   1760.0          587.0     67922.0           7661.0
# 3                   1826.0          630.0     50036.0           5538.0
# 4                   1543.0          482.0     37946.0           6234.0

# %% [markdown]
# >El siguiente paso es traer el Sheet número 5, el cual tiene los datos de lugares a los que los mexicanos han migrado.

# %%
df_INEGI_Yr2020_5 = pd.read_excel(r"/Users/stefa/REPO_PRUEBA/EDA_Proyecto/src/data/cpv2020.xlsx",sheet_name="05",skiprows=[0,1,2,3,4,5],usecols="A:D,J:N") #Se observa que se traen las columnas que únicamente necesitamos para nuestro análisis
df_INEGI_Yr2020_5.head(5)
# Out:
#                            Unnamed: 0                Unnamed: 1 Unnamed: 2  \
# 0                                 NaN                       NaN        NaN
# 1                                 NaN                       NaN        NaN
# 2       Estados Unidos MexicanosTotal  Estados Unidos Mexicanos      Total
# 3  Estados Unidos Mexicanos05-09 años  Estados Unidos Mexicanos      Total
# 4  Estados Unidos Mexicanos10-14 años  Estados Unidos Mexicanos      Total
#
#    Unnamed: 3 En otra entidad o país      Unnamed: 10  \
# 0         NaN                  Total  En otra entidad
# 1         NaN                    NaN              NaN
# 2       Total                4357929          3807844
# 3  05-09 años                 385509           353149
# 4  10-14 años                 334988           304784
#
#                         Unnamed: 11   Unnamed: 12  No especificado
# 0  En los Estados Unidos de América  En otro país              NaN
# 1                               NaN           NaN              NaN
# 2                            374155        175930         259750.0
# 3                             20662         11698          13876.0
# 4                             20721          9483           8895.0

# %% [markdown]
# >En este apartado se renombran las columnas puesto que el Excel esta bloqueado y no se pueden modificar manualmente en el excel, por lo cual se ha tenido que utilizar las herramientas de pandas para nombrar las columnas como en la tabla anterior

# %%
df_INEGI_Yr2020_5.rename(columns ={"Unnamed: 0":"Unicode","Unnamed: 1":"Entidad Federativa de residencia actual","Unnamed: 2":"Género","Unnamed: 3": "Grupos quinquenales de edad","En otra entidad del país":"Total en otra entidad del país","Unnamed: 10":"En otra entidad","Unnamed: 11":"En los Estados Unidos de América","Unnamed: 12":"En otro país"},inplace=True)
df_INEGI_Yr2020_5 #se renombran las columnas utilizando pandas
# Out:
#                                  Unicode  \
# 0                                    NaN
# 1                                    NaN
# 2          Estados Unidos MexicanosTotal
# 3     Estados Unidos Mexicanos05-09 años
# 4     Estados Unidos Mexicanos10-14 años
# ...                                  ...
# 1779              32 Zacatecas65-69 años
# 1780              32 Zacatecas70-74 años
# 1781              32 Zacatecas75-79 años
# 1782              32 Zacatecas80-84 años
# 1783           32 Zacatecas85 años y más
#
#      Entidad Federativa de residencia actual   Género  \
# 0                                        NaN      NaN
# 1                                        NaN      NaN
# 2                   Estados Unidos Mexicanos    Total
# 3                   Estados Unidos Mexicanos    Total
# 4                   Estados Unidos Mexicanos    Total
# ...                                      ...      ...
# 1779                            32 Zacatecas  Mujeres
# 1780                            32 Zacatecas  Mujeres
# 1781                            32 Zacatecas  Mujeres
# 1782                            32 Zacatecas  Mujeres
# 1783                            32 Zacatecas  Mujeres
#
#      Grupos quinquenales de edad En otra entidad o país  En otra entidad  \
# 0                            NaN                  Total  En otra entidad
# 1                            NaN                    NaN              NaN
# 2                          Total                4357929          3807844
# 3                     05-09 años                 385509           353149
# 4                     10-14 años                 334988           304784
# ...                          ...                    ...              ...
# 1779                  65-69 años                    387              224
# 1780                  70-74 años                    214              130
# 1781                  75-79 años                    160               97
# 1782                  80-84 años                     85               57
# 1783               85 años y más                    118               83
#
#       En los Estados Unidos de América  En otro país  No especificado
# 0     En los Estados Unidos de América  En otro país              NaN
# 1                                  NaN           NaN              NaN
# 2                               374155        175930         259750.0
# 3                                20662         11698          13876.0
# 4                                20721          9483           8895.0
# ...                                ...           ...              ...
# 1779                               162             1             11.0
# 1780                                84             0             12.0
# 1781                                63             0              5.0
# 1782                                28             0              5.0
# 1783                                34             1              2.0
#
# [1784 rows x 9 columns]

# %% [markdown]
# ### Limpieza de datos (paso 1)  <a id="limpieza"></a>
#
# #### Tabla 07

# %%
df_INEGI_Yr2020_07.info() #aunque pareciera que no hay nulos, en la tabla de abajo podemos ver que hay líneas enteras que contienen Nulos, las cuales hay que eliminar

df_INEGI_Yr2020_07.loc[df_INEGI_Yr2020_07 ["Entidad Federativa de residencia actual"].isna()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1785 entries, 0 to 1784
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unicode                                  1782 non-null   object
#  1   Entidad Federativa de residencia actual  1783 non-null   object
#  2   Género                                   1782 non-null   object
#  3   Grupos quinquenales de edad              1782 non-null   object
#  4   Población de 5 años y más migrante       1782 non-null   float64
#  5   Buscar trabajo                           1782 non-null   float64
#  6   Cambio u oferta de trabajo               1782 non-null   float64
#  7   Reunirse con la familia                  1782 non-null   float64
#  8   Se casó o unió                           1782 non-null   float64
#  9   Estudiar                                 1782 non-null   float64
#  10  Por inseguridad delictiva o violencia    1782 non-null   float64
#  11  Por desastres naturales                  1782 non-null   float64
#  12  Lo deportaron                            1782 non-null   float64
#  13  Otra causa                               1782 non-null   float64
#  14  No especificado                          1782 non-null   float64
# dtypes: float64(11), object(4)
# memory usage: 209.3+ KB
#      Unicode Entidad Federativa de residencia actual Género  \
# 0        NaN                                     NaN    NaN
# 1783     NaN                                     NaN    NaN
#
#      Grupos quinquenales de edad  Población de 5 años y más migrante  \
# 0                            NaN                                 NaN
# 1783                         NaN                                 NaN
#
#       Buscar trabajo  Cambio u oferta de trabajo  Reunirse con la familia  \
# 0                NaN                         NaN                      NaN
# 1783             NaN                         NaN                      NaN
#
#       Se casó o unió  Estudiar  Por inseguridad delictiva o violencia  \
# 0                NaN       NaN                                    NaN
# 1783             NaN       NaN                                    NaN
#
#       Por desastres naturales  Lo deportaron  Otra causa  No especificado
# 0                         NaN            NaN         NaN              NaN
# 1783                      NaN            NaN         NaN              NaN

# %%
df_INEGI_Yr2020_07.drop([0],inplace=True) #Se elimina la primera fila de NaN a través de Index 0
df_INEGI_Yr2020_07.dropna(inplace=True) #Se eliminan los NaN de otras filas
df_INEGI_Yr2020_07.head(5)
# Out:
#                               Unicode Entidad Federativa de residencia actual  \
# 1       Estados Unidos MexicanosTotal                Estados Unidos Mexicanos
# 2  Estados Unidos Mexicanos05-09 años                Estados Unidos Mexicanos
# 3  Estados Unidos Mexicanos10-14 años                Estados Unidos Mexicanos
# 4  Estados Unidos Mexicanos15-19 años                Estados Unidos Mexicanos
# 5  Estados Unidos Mexicanos20-24 años                Estados Unidos Mexicanos
#
#   Género Grupos quinquenales de edad  Población de 5 años y más migrante  \
# 1  Total                       Total                           6888490.0
# 2  Total                  05-09 años                            624339.0
# 3  Total                  10-14 años                            542634.0
# 4  Total                  15-19 años                            595630.0
# 5  Total                  20-24 años                            864222.0
#
#    Buscar trabajo  Cambio u oferta de trabajo  Reunirse con la familia  \
# 1       1129177.0                    855435.0                2515611.0
# 2             0.0                         0.0                 479214.0
# 3          6758.0                      7067.0                 385222.0
# 4         73319.0                     22189.0                 270949.0
# 5        208504.0                     73593.0                 203711.0
#
#    Se casó o unió  Estudiar  Por inseguridad delictiva o violencia  \
# 1        636148.0  463170.0                               274158.0
# 2             0.0   42379.0                                24816.0
# 3          1102.0   58274.0                                26181.0
# 4         41917.0  117612.0                                23439.0
# 5        130552.0  164553.0                                20802.0
#
#    Por desastres naturales  Lo deportaron  Otra causa  No especificado
# 1                  24742.0        41390.0    860165.0          88494.0
# 2                   1760.0          587.0     67922.0           7661.0
# 3                   1826.0          630.0     50036.0           5538.0
# 4                   1543.0          482.0     37946.0           6234.0
# 5                   1394.0         1704.0     49431.0           9978.0

# %%
df_INEGI_Yr2020_07.loc[df_INEGI_Yr2020_07 ["Entidad Federativa de residencia actual"].isna()] #Corroboramos que no haya más Nulos
# Out:
# Empty DataFrame
# Columns: [Unicode, Entidad Federativa de residencia actual, Género, Grupos quinquenales de edad, Población de 5 años y más migrante, Buscar trabajo, Cambio u oferta de trabajo, Reunirse con la familia, Se casó o unió, Estudiar, Por inseguridad delictiva o violencia, Por desastres naturales, Lo deportaron, Otra causa, No especificado]
# Index: []

# %%
#mask_drop_GQuin_07 = df_INEGI_Yr2020_07['Grupos quinquenales de edad'] == 'Total' 
''' 27072024 Se elimina el Total de Grupos quinquenales de edad utlizando una máscara ya que el total lo podemos calcular utilizando python
'''
''' 272072024 al continuar con el ejercicio, nos percatamos que las filas de Total las ocuparemos para el Análisis de datos
'''
#df_INEGI_Yr2020_07 = df_INEGI_Yr2020_07 [~mask_drop_GQuin_07]
#df_INEGI_Yr2020_07.head(5)
# Out:
# ' 272072024 al continuar con el ejercicio, nos percatamos que las filas de Total las ocuparemos para el Análisis de datos\n'

# %% [markdown]
# #### Tabla 05

# %%
df_INEGI_Yr2020_5.info() #aunque pareciera que no hay nulos, en la tabla de abajo podemos ver que hay líneas enteras que contienen Nulos, las cuales hay que eliminar

df_INEGI_Yr2020_5.loc[df_INEGI_Yr2020_5 ["Entidad Federativa de residencia actual"].isna()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1784 entries, 0 to 1783
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unicode                                  1782 non-null   object
#  1   Entidad Federativa de residencia actual  1782 non-null   object
#  2   Género                                   1782 non-null   object
#  3   Grupos quinquenales de edad              1782 non-null   object
#  4   En otra entidad o país                   1783 non-null   object
#  5   En otra entidad                          1783 non-null   object
#  6   En los Estados Unidos de América         1783 non-null   object
#  7   En otro país                             1783 non-null   object
#  8   No especificado                          1782 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 125.6+ KB
#   Unicode Entidad Federativa de residencia actual Género  \
# 0     NaN                                     NaN    NaN
# 1     NaN                                     NaN    NaN
#
#   Grupos quinquenales de edad En otra entidad o país  En otra entidad  \
# 0                         NaN                  Total  En otra entidad
# 1                         NaN                    NaN              NaN
#
#    En los Estados Unidos de América  En otro país  No especificado
# 0  En los Estados Unidos de América  En otro país              NaN
# 1                               NaN           NaN              NaN

# %%
df_INEGI_Yr2020_5.drop([0],inplace=True) #Se elimina la primera fila de NaN a través de Index 0
df_INEGI_Yr2020_5.dropna(inplace=True) #Se eliminan los NaN de otras filas
df_INEGI_Yr2020_5.head(5)
# Out:
#                               Unicode Entidad Federativa de residencia actual  \
# 2       Estados Unidos MexicanosTotal                Estados Unidos Mexicanos
# 3  Estados Unidos Mexicanos05-09 años                Estados Unidos Mexicanos
# 4  Estados Unidos Mexicanos10-14 años                Estados Unidos Mexicanos
# 5  Estados Unidos Mexicanos15-19 años                Estados Unidos Mexicanos
# 6  Estados Unidos Mexicanos20-24 años                Estados Unidos Mexicanos
#
#   Género Grupos quinquenales de edad En otra entidad o país En otra entidad  \
# 2  Total                       Total                4357929         3807844
# 3  Total                  05-09 años                 385509          353149
# 4  Total                  10-14 años                 334988          304784
# 5  Total                  15-19 años                 371644          345520
# 6  Total                  20-24 años                 553636          515834
#
#   En los Estados Unidos de América En otro país  No especificado
# 2                           374155       175930         259750.0
# 3                            20662        11698          13876.0
# 4                            20721         9483           8895.0
# 5                            15908        10216          10996.0
# 6                            19721        18081          26457.0

# %%
df_INEGI_Yr2020_5.loc[df_INEGI_Yr2020_5 ["Entidad Federativa de residencia actual"].isna()] #Corroboramos que no haya más Nulos
# Out:
# Empty DataFrame
# Columns: [Unicode, Entidad Federativa de residencia actual, Género, Grupos quinquenales de edad, En otra entidad o país, En otra entidad, En los Estados Unidos de América, En otro país, No especificado]
# Index: []

# %%
#mask_drop_GQuin_5 = df_INEGI_Yr2020_5['Grupos quinquenales de edad'] == 'Total' 
'''Se elimina el Total de Grupos quinquenales de edad utlizando una máscara ya que el total lo podemos calcular utilizando python
'''

''' 27072024 Se elimina el Total de Grupos quinquenales de edad utlizando una máscara ya que el total lo podemos calcular utilizando python
'''
''' 272072024 al continuar con el ejercicio, nos percatamos que las filas de Total las ocuparemos para el Análisis de datos
'''
#df_INEGI_Yr2020_5 = df_INEGI_Yr2020_5 [~mask_drop_GQuin_5]
#df_INEGI_Yr2020_5.head(5)
# Out:
# ' 272072024 al continuar con el ejercicio, nos percatamos que las filas de Total las ocuparemos para el Análisis de datos\n'

# %% [markdown]
# ### Unificación de valores de las tablas <a id="unificacion"></a>
#
# *En esta sección hacemos la combinación de las tablas 07 y 5. Sin embargo, podemos ver que se han creados una **segunda limpieza** tendrá que llevarse acabo*
#
# > Antes de continuar con la limpieza se ha observado que las filas han incrementadp de 1683 en cada tabla a 85833 por lo que procedemos a verificar
# la solución que se encontró fue crear una nueva columna llamada "Unicode" la cual ayuda a unificar mediante un único valor que tenga como referencia
# la *Entidad Federativa de residencia actual* y los *Grupos quinquenales de edad* reduciendo las líneas a 5049 como se aprecia en la tabla de abajo.

# %%
df_INEGI_merged = df_INEGI_Yr2020_07.merge(df_INEGI_Yr2020_5, how='inner',on="Unicode") #Combinación de tablas 07 y 5
df_INEGI_merged
# Out:
#                                  Unicode  \
# 0          Estados Unidos MexicanosTotal
# 1          Estados Unidos MexicanosTotal
# 2          Estados Unidos MexicanosTotal
# 3     Estados Unidos Mexicanos05-09 años
# 4     Estados Unidos Mexicanos05-09 años
# ...                                  ...
# 5341              32 Zacatecas80-84 años
# 5342              32 Zacatecas80-84 años
# 5343           32 Zacatecas85 años y más
# 5344           32 Zacatecas85 años y más
# 5345           32 Zacatecas85 años y más
#
#      Entidad Federativa de residencia actual_x Género_x  \
# 0                     Estados Unidos Mexicanos    Total
# 1                     Estados Unidos Mexicanos    Total
# 2                     Estados Unidos Mexicanos    Total
# 3                     Estados Unidos Mexicanos    Total
# 4                     Estados Unidos Mexicanos    Total
# ...                                        ...      ...
# 5341                              32 Zacatecas  Mujeres
# 5342                              32 Zacatecas  Mujeres
# 5343                              32 Zacatecas  Mujeres
# 5344                              32 Zacatecas  Mujeres
# 5345                              32 Zacatecas  Mujeres
#
#      Grupos quinquenales de edad_x  Población de 5 años y más migrante  \
# 0                            Total                           6888490.0
# 1                            Total                           6888490.0
# 2                            Total                           6888490.0
# 3                       05-09 años                            624339.0
# 4                       05-09 años                            624339.0
# ...                            ...                                 ...
# 5341                    80-84 años                               149.0
# 5342                    80-84 años                               149.0
# 5343                 85 años y más                               193.0
# 5344                 85 años y más                               193.0
# 5345                 85 años y más                               193.0
#
#       Buscar trabajo  Cambio u oferta de trabajo  Reunirse con la familia  \
# 0          1129177.0                    855435.0                2515611.0
# 1          1129177.0                    855435.0                2515611.0
# 2          1129177.0                    855435.0                2515611.0
# 3                0.0                         0.0                 479214.0
# 4                0.0                         0.0                 479214.0
# ...              ...                         ...                      ...
# 5341             2.0                         6.0                     97.0
# 5342             2.0                         6.0                     97.0
# 5343             1.0                         2.0                    129.0
# 5344             1.0                         2.0                    129.0
# 5345             1.0                         2.0                    129.0
#
#       Se casó o unió  Estudiar  ...  Otra causa  No especificado_x  \
# 0           636148.0  463170.0  ...    860165.0            88494.0
# 1           636148.0  463170.0  ...    860165.0            88494.0
# 2           636148.0  463170.0  ...    860165.0            88494.0
# 3                0.0   42379.0  ...     67922.0             7661.0
# 4                0.0   42379.0  ...     67922.0             7661.0
# ...              ...       ...  ...         ...                ...
# 5341             0.0       0.0  ...        40.0                2.0
# 5342             0.0       0.0  ...        40.0                2.0
# 5343             0.0       0.0  ...        58.0                3.0
# 5344             0.0       0.0  ...        58.0                3.0
# 5345             0.0       0.0  ...        58.0                3.0
#
#       Entidad Federativa de residencia actual_y  Género_y  \
# 0                      Estados Unidos Mexicanos     Total
# 1                      Estados Unidos Mexicanos   Hombres
# 2                      Estados Unidos Mexicanos   Mujeres
# 3                      Estados Unidos Mexicanos     Total
# 4                      Estados Unidos Mexicanos   Hombres
# ...                                         ...       ...
# 5341                               32 Zacatecas   Hombres
# 5342                               32 Zacatecas   Mujeres
# 5343                               32 Zacatecas     Total
# 5344                               32 Zacatecas   Hombres
# 5345                               32 Zacatecas   Mujeres
#
#       Grupos quinquenales de edad_y En otra entidad o país En otra entidad  \
# 0                             Total                4357929         3807844
# 1                             Total                2270686         1917858
# 2                             Total                2087243         1889986
# 3                        05-09 años                 385509          353149
# 4                        05-09 años                 194822          178194
# ...                             ...                    ...             ...
# 5341                     80-84 años                     95              49
# 5342                     80-84 años                     85              57
# 5343                  85 años y más                    201             129
# 5344                  85 años y más                     83              46
# 5345                  85 años y más                    118              83
#
#      En los Estados Unidos de América En otro país No especificado_y
# 0                              374155       175930          259750.0
# 1                              260001        92827          202210.0
# 2                              114154        83103           57540.0
# 3                               20662        11698           13876.0
# 4                               10544         6084            7025.0
# ...                               ...          ...               ...
# 5341                               46            0               4.0
# 5342                               28            0               5.0
# 5343                               71            1               4.0
# 5344                               37            0               2.0
# 5345                               34            1               2.0
#
# [5346 rows x 23 columns]

# %% [markdown]
# ### Limpieza de datos (paso 2)  <a id="limpieza2"></a>
#
# #### Tabla merged
#
# > En este apartado verificamos que no haya NaN

# %%
df_INEGI_merged.columns #Nos ayudamos a visualizar mejor los nombres de las columnas trayendo los headers de las mismas
# Out:
# Index(['Unicode', 'Entidad Federativa de residencia actual_x', 'Género_x',
#        'Grupos quinquenales de edad_x', 'Población de 5 años y más migrante',
#        'Buscar trabajo', 'Cambio u oferta de trabajo',
#        'Reunirse con la familia', 'Se casó o unió', 'Estudiar',
#        'Por inseguridad delictiva o violencia', 'Por desastres naturales',
#        'Lo deportaron', 'Otra causa', 'No especificado_x',
#        'Entidad Federativa de residencia actual_y', 'Género_y',
#        'Grupos quinquenales de edad_y', 'En otra entidad o país',
#        'En otra entidad', 'En los Estados Unidos de América', 'En otro país',
#        'No especificado_y'],
#       dtype='object')

# %%
df_INEGI_merged.info() #verificamos los nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5346 entries, 0 to 5345
# Data columns (total 23 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unicode                                    5346 non-null   object
#  1   Entidad Federativa de residencia actual_x  5346 non-null   object
#  2   Género_x                                   5346 non-null   object
#  3   Grupos quinquenales de edad_x              5346 non-null   object
#  4   Población de 5 años y más migrante         5346 non-null   float64
#  5   Buscar trabajo                             5346 non-null   float64
#  6   Cambio u oferta de trabajo                 5346 non-null   float64
#  7   Reunirse con la familia                    5346 non-null   float64
#  8   Se casó o unió                             5346 non-null   float64
#  9   Estudiar                                   5346 non-null   float64
#  10  Por inseguridad delictiva o violencia      5346 non-null   float64
#  11  Por desastres naturales                    5346 non-null   float64
#  12  Lo deportaron                              5346 non-null   float64
#  13  Otra causa                                 5346 non-null   float64
#  14  No especificado_x                          5346 non-null   float64
#  15  Entidad Federativa de residencia actual_y  5346 non-null   object
#  16  Género_y                                   5346 non-null   object
#  17  Grupos quinquenales de edad_y              5346 non-null   object
#  18  En otra entidad o país                     5346 non-null   object
#  19  En otra entidad                            5346 non-null   object
#  20  En los Estados Unidos de América           5346 non-null   object
#  21  En otro país                               5346 non-null   object
#  22  No especificado_y                          5346 non-null   float64
# dtypes: float64(12), object(11)
# memory usage: 960.7+ KB

# %%
df_INEGI_merged.dropna(inplace=True) #nos aseguramos que no haya nulos con la fórmula dropna
df_INEGI_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5346 entries, 0 to 5345
# Data columns (total 23 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unicode                                    5346 non-null   object
#  1   Entidad Federativa de residencia actual_x  5346 non-null   object
#  2   Género_x                                   5346 non-null   object
#  3   Grupos quinquenales de edad_x              5346 non-null   object
#  4   Población de 5 años y más migrante         5346 non-null   float64
#  5   Buscar trabajo                             5346 non-null   float64
#  6   Cambio u oferta de trabajo                 5346 non-null   float64
#  7   Reunirse con la familia                    5346 non-null   float64
#  8   Se casó o unió                             5346 non-null   float64
#  9   Estudiar                                   5346 non-null   float64
#  10  Por inseguridad delictiva o violencia      5346 non-null   float64
#  11  Por desastres naturales                    5346 non-null   float64
#  12  Lo deportaron                              5346 non-null   float64
#  13  Otra causa                                 5346 non-null   float64
#  14  No especificado_x                          5346 non-null   float64
#  15  Entidad Federativa de residencia actual_y  5346 non-null   object
#  16  Género_y                                   5346 non-null   object
#  17  Grupos quinquenales de edad_y              5346 non-null   object
#  18  En otra entidad o país                     5346 non-null   object
#  19  En otra entidad                            5346 non-null   object
#  20  En los Estados Unidos de América           5346 non-null   object
#  21  En otro país                               5346 non-null   object
#  22  No especificado_y                          5346 non-null   float64
# dtypes: float64(12), object(11)
# memory usage: 960.7+ KB

# %%
df_INEGI_merged.loc[df_INEGI_merged["Entidad Federativa de residencia actual_y"].isna()] #hacemos un random check de nulos a través de la columna "Entidad Federativa de residencia actual"
# Out:
# Empty DataFrame
# Columns: [Unicode, Entidad Federativa de residencia actual_x, Género_x, Grupos quinquenales de edad_x, Población de 5 años y más migrante, Buscar trabajo, Cambio u oferta de trabajo, Reunirse con la familia, Se casó o unió, Estudiar, Por inseguridad delictiva o violencia, Por desastres naturales, Lo deportaron, Otra causa, No especificado_x, Entidad Federativa de residencia actual_y, Género_y, Grupos quinquenales de edad_y, En otra entidad o país, En otra entidad, En los Estados Unidos de América, En otro país, No especificado_y]
# Index: []
#
# [0 rows x 23 columns]

# %%
#En esta parte eliminamos las columnas repetidas para ir dejando nuestra base datos lo más simple y limpia posible

df_INEGI_merged.drop("Grupos quinquenales de edad_y",axis=1,inplace=True) 
df_INEGI_merged.drop("Género_y",axis=1,inplace=True)

# %%
df_INEGI_merged.head(1)
# Out:
#                          Unicode Entidad Federativa de residencia actual_x  \
# 0  Estados Unidos MexicanosTotal                  Estados Unidos Mexicanos
#
#   Género_x Grupos quinquenales de edad_x  Población de 5 años y más migrante  \
# 0    Total                         Total                           6888490.0
#
#    Buscar trabajo  Cambio u oferta de trabajo  Reunirse con la familia  \
# 0       1129177.0                    855435.0                2515611.0
#
#    Se casó o unió  Estudiar  ...  Por desastres naturales  Lo deportaron  \
# 0        636148.0  463170.0  ...                  24742.0        41390.0
#
#    Otra causa  No especificado_x  Entidad Federativa de residencia actual_y  \
# 0    860165.0            88494.0                   Estados Unidos Mexicanos
#
#   En otra entidad o país En otra entidad En los Estados Unidos de América  \
# 0                4357929         3807844                           374155
#
#   En otro país No especificado_y
# 0       175930          259750.0
#
# [1 rows x 21 columns]

# %%
'''Se crea una nueva columna para igualar los datos referentes a las causas de migración vs lugar de residencia, la diferencia entre ambos totales 
se asigna en la nueva columna de datos no especificados de aquel Total que tuvo menos datos que en este caso es el lugar de residencia
'''

df_INEGI_merged ["No_especificado_lugar_residencia"] = (df_INEGI_merged["Población de 5 años y más migrante"] - df_INEGI_merged ["En otra entidad o país"])

# %%
#calineamos el total de población de la categoría de "causas de la migración" en la categoría "Residen en otro lugar"
df_INEGI_merged ["Total_residen_en_otro_lugar"] = (df_INEGI_merged["En otra entidad o país"] + df_INEGI_merged ["No_especificado_lugar_residencia"])

# %%
df_INEGI_merged.drop("En otra entidad o país",axis=1,inplace=True)  #Se elimina el total que estaba incompleto

# %% [markdown]
# *Vemos que ahora tanto el total de Poblacion de 5 años que se refiere al total de causas de migración como el total reside en otro lugar es exactamente el mismo*

# %%
df_INEGI_merged.head(1)
# Out:
#                          Unicode Entidad Federativa de residencia actual_x  \
# 0  Estados Unidos MexicanosTotal                  Estados Unidos Mexicanos
#
#   Género_x Grupos quinquenales de edad_x  Población de 5 años y más migrante  \
# 0    Total                         Total                           6888490.0
#
#    Buscar trabajo  Cambio u oferta de trabajo  Reunirse con la familia  \
# 0       1129177.0                    855435.0                2515611.0
#
#    Se casó o unió  Estudiar  ...  Lo deportaron  Otra causa  \
# 0        636148.0  463170.0  ...        41390.0    860165.0
#
#    No especificado_x  Entidad Federativa de residencia actual_y  \
# 0            88494.0                   Estados Unidos Mexicanos
#
#    En otra entidad En los Estados Unidos de América En otro país  \
# 0          3807844                           374155       175930
#
#   No especificado_y No_especificado_lugar_residencia  \
# 0          259750.0                        2530561.0
#
#    Total_residen_en_otro_lugar
# 0                    6888490.0
#
# [1 rows x 22 columns]

# %% [markdown]
# > Incialmente se pensó que se podría unificar los No especificados e igualarlos en el total más grande que en este caso era el
# del total de la población, pero al tratar de comenzar con el análisis, nos damos cuenta que necesitamos el total por categoría para poder hacer comparativas que en este caso son:
#
# * Categoría 1 - Causas de la migración
# >
# >
# * categoría 2 - Lugar de residencia

# %%
#df_INEGI_merged.drop("No especificado_x",axis=1,inplace=True)

# %% [markdown]
# *Sin embargo al continuar con la limpieza y renombrando las columnas, al alinear el n. total de población para el total de residen en otro lugar y la diferencia ponerla en una nueva columna llamada No especificado lugar de residencia, vemos que la columna No especificado_y se puede eliminar ya. Así mismo hemos identificado que la columna Entidad Federativa de residencia actual_y estaba duplicada así que la eliminamos*

# %%
df_INEGI_merged.drop("No especificado_y",axis=1,inplace=True)
df_INEGI_merged.drop("Entidad Federativa de residencia actual_y",axis=1,inplace=True)

# %% [markdown]
# *En este apartado vamos a renombrar las columnas para poder identificarlas con más facilidad*

# %%
df_INEGI_merged.columns
# Out:
# Index(['Unicode', 'Entidad Federativa de residencia actual_x', 'Género_x',
#        'Grupos quinquenales de edad_x', 'Población de 5 años y más migrante',
#        'Buscar trabajo', 'Cambio u oferta de trabajo',
#        'Reunirse con la familia', 'Se casó o unió', 'Estudiar',
#        'Por inseguridad delictiva o violencia', 'Por desastres naturales',
#        'Lo deportaron', 'Otra causa', 'No especificado_x', 'En otra entidad',
#        'En los Estados Unidos de América', 'En otro país',
#        'No_especificado_lugar_residencia', 'Total_residen_en_otro_lugar'],
#       dtype='object')

# %%
df_INEGI_merged.rename(columns ={"Entidad Federativa de residencia actual_x":"Entidad_Federativa","Género_x":"Género","Grupos quinquenales de edad_x":"Grupos_de_edad","Población de 5 años y más migrante": "Total_Causas_Migración","En otra entidad o país":"Total_residen_en_otro_lugar","No especificado_x":"No_especificado_causas"},inplace=True)
df_INEGI_merged.head(2) #se renombran las columnas utilizando pandas
# Out:
#                          Unicode        Entidad_Federativa Género  \
# 0  Estados Unidos MexicanosTotal  Estados Unidos Mexicanos  Total
# 1  Estados Unidos MexicanosTotal  Estados Unidos Mexicanos  Total
#
#   Grupos_de_edad  Total_Causas_Migración  Buscar trabajo  \
# 0          Total               6888490.0       1129177.0
# 1          Total               6888490.0       1129177.0
#
#    Cambio u oferta de trabajo  Reunirse con la familia  Se casó o unió  \
# 0                    855435.0                2515611.0        636148.0
# 1                    855435.0                2515611.0        636148.0
#
#    Estudiar  Por inseguridad delictiva o violencia  Por desastres naturales  \
# 0  463170.0                               274158.0                  24742.0
# 1  463170.0                               274158.0                  24742.0
#
#    Lo deportaron  Otra causa  No_especificado_causas En otra entidad  \
# 0        41390.0    860165.0                 88494.0         3807844
# 1        41390.0    860165.0                 88494.0         1917858
#
#   En los Estados Unidos de América En otro país  \
# 0                           374155       175930
# 1                           260001        92827
#
#   No_especificado_lugar_residencia Total_residen_en_otro_lugar
# 0                        2530561.0                   6888490.0
# 1                        4617804.0                   6888490.0

# %%
df_INEGI_merged.columns #verificamos el numbre de las columnas
# Out:
# Index(['Unicode', 'Entidad_Federativa', 'Género', 'Grupos_de_edad',
#        'Total_Causas_Migración', 'Buscar trabajo',
#        'Cambio u oferta de trabajo', 'Reunirse con la familia',
#        'Se casó o unió', 'Estudiar', 'Por inseguridad delictiva o violencia',
#        'Por desastres naturales', 'Lo deportaron', 'Otra causa',
#        'No_especificado_causas', 'En otra entidad',
#        'En los Estados Unidos de América', 'En otro país',
#        'No_especificado_lugar_residencia', 'Total_residen_en_otro_lugar'],
#       dtype='object')

# %% [markdown]
# ### Inicio del Análsis  <a id="analisis"></a>
#
# Verificaremos si los motivos que conllevan a la migración de México influyen en que la migración sea en los Estados Unidos de América u en otros países.

# %%
def separa_nombre(nombre):
    nuevo = nombre[0]
    for letra in nombre[1:]:
        if letra == letra.upper():
            nuevo += " "
        nuevo += letra
    return nuevo

ciudades_mas_pobladas = df_INEGI_merged.loc[df_INEGI_merged.Población de 5 años y más migrante_x.nlargest(5).index, 
                                    ["Entidad Federativa de residencia actual_x","Población de 5 años y más migrante_x"]]
ciudades = [ separa_nombre(Entidad Federativa de residencia actual_x) for Entidad Federativa de residencia actual_x in ciudades_mas_pobladas["Entidad Federativa de residencia actual_x"].to_list()]
colores = ["blue","gray","red","olive","brown"]
plt.figure(figsize = (10,5))
plt.bar(x= ciudades, height= ciudades_mas_pobladas["Población de 5 años y más migrante_x"]/1000, color = colores, alpha = 0.5)
plt.ylim([0,5000])
plt.ylabel("Habitantes (miles)")
plt.xlabel("Ciudades")

ciudades_mas_pobladas.set_index("Entidad Federativa de residencia actual_x", inplace = True)
for indice, ciudad in enumerate(ciudades_mas_pobladas.index):
    poblacion = ciudades_mas_pobladas.loc[ciudad,"Población de 5 años y más migrante_x"]/1000
    plt.text(ciudades[indice], poblacion + 50, f"{poblacion}", ha = "center")
plt.title("Ciudades más pobladas de California")
plt.show()
# Out:
#   Cell In[30], line 9
#     ciudades_mas_pobladas = df_INEGI_merged.loc[df_INEGI_merged.Población de 5 años y más migrante_x.nlargest(5).index,
#                                                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
def

# %%
df_INEGI_merged.head(15)
# Out:
#                                Unicode  \
# 0        Estados Unidos MexicanosTotal
# 1        Estados Unidos MexicanosTotal
# 2        Estados Unidos MexicanosTotal
# 3   Estados Unidos Mexicanos05-09 años
# 4   Estados Unidos Mexicanos05-09 años
# 5   Estados Unidos Mexicanos05-09 años
# 6   Estados Unidos Mexicanos10-14 años
# 7   Estados Unidos Mexicanos10-14 años
# 8   Estados Unidos Mexicanos10-14 años
# 9   Estados Unidos Mexicanos15-19 años
# 10  Estados Unidos Mexicanos15-19 años
# 11  Estados Unidos Mexicanos15-19 años
# 12  Estados Unidos Mexicanos20-24 años
# 13  Estados Unidos Mexicanos20-24 años
# 14  Estados Unidos Mexicanos20-24 años
#
#    Entidad Federativa de residencia actual_x Género_x  \
# 0                   Estados Unidos Mexicanos    Total
# 1                   Estados Unidos Mexicanos    Total
# 2                   Estados Unidos Mexicanos    Total
# 3                   Estados Unidos Mexicanos    Total
# 4                   Estados Unidos Mexicanos    Total
# 5                   Estados Unidos Mexicanos    Total
# 6                   Estados Unidos Mexicanos    Total
# 7                   Estados Unidos Mexicanos    Total
# 8                   Estados Unidos Mexicanos    Total
# 9                   Estados Unidos Mexicanos    Total
# 10                  Estados Unidos Mexicanos    Total
# 11                  Estados Unidos Mexicanos    Total
# 12                  Estados Unidos Mexicanos    Total
# 13                  Estados Unidos Mexicanos    Total
# 14                  Estados Unidos Mexicanos    Total
#
#    Grupos quinquenales de edad_x  Población de 5 años y más migrante_x  \
# 0                          Total                             6888490.0
# 1                          Total                             6888490.0
# 2                          Total                             6888490.0
# 3                     05-09 años                              624339.0
# 4                     05-09 años                              624339.0
# 5                     05-09 años                              624339.0
# 6                     10-14 años                              542634.0
# 7                     10-14 años                              542634.0
# 8                     10-14 años                              542634.0
# 9                     15-19 años                              595630.0
# 10                    15-19 años                              595630.0
# 11                    15-19 años                              595630.0
# 12                    20-24 años                              864222.0
# 13                    20-24 años                              864222.0
# 14                    20-24 años                              864222.0
#
#     Buscar trabajo  Cambio u oferta de trabajo  Reunirse con la familia  \
# 0        1129177.0                    855435.0                2515611.0
# 1        1129177.0                    855435.0                2515611.0
# 2        1129177.0                    855435.0                2515611.0
# 3              0.0                         0.0                 479214.0
# 4              0.0                         0.0                 479214.0
# 5              0.0                         0.0                 479214.0
# 6           6758.0                      7067.0                 385222.0
# 7           6758.0                      7067.0                 385222.0
# 8           6758.0                      7067.0                 385222.0
# 9          73319.0                     22189.0                 270949.0
# 10         73319.0                     22189.0                 270949.0
# 11         73319.0                     22189.0                 270949.0
# 12        208504.0                     73593.0                 203711.0
# 13        208504.0                     73593.0                 203711.0
# 14        208504.0                     73593.0                 203711.0
#
#     Se casó o unió  Estudiar  ...  No especificado_x  \
# 0         636148.0  463170.0  ...            88494.0
# 1         636148.0  463170.0  ...            88494.0
# 2         636148.0  463170.0  ...            88494.0
# 3              0.0   42379.0  ...             7661.0
# 4              0.0   42379.0  ...             7661.0
# 5              0.0   42379.0  ...             7661.0
# 6           1102.0   58274.0  ...             5538.0
# 7           1102.0   58274.0  ...             5538.0
# 8           1102.0   58274.0  ...             5538.0
# 9          41917.0  117612.0  ...             6234.0
# 10         41917.0  117612.0  ...             6234.0
# 11         41917.0  117612.0  ...             6234.0
# 12        130552.0  164553.0  ...             9978.0
# 13        130552.0  164553.0  ...             9978.0
# 14        130552.0  164553.0  ...             9978.0
#
#     Entidad Federativa de residencia actual_y  Género_y  \
# 0                    Estados Unidos Mexicanos     Total
# 1                    Estados Unidos Mexicanos   Hombres
# 2                    Estados Unidos Mexicanos   Mujeres
# 3                    Estados Unidos Mexicanos     Total
# 4                    Estados Unidos Mexicanos   Hombres
# 5                    Estados Unidos Mexicanos   Mujeres
# 6                    Estados Unidos Mexicanos     Total
# 7                    Estados Unidos Mexicanos   Hombres
# 8                    Estados Unidos Mexicanos   Mujeres
# 9                    Estados Unidos Mexicanos     Total
# 10                   Estados Unidos Mexicanos   Hombres
# 11                   Estados Unidos Mexicanos   Mujeres
# 12                   Estados Unidos Mexicanos     Total
# 13                   Estados Unidos Mexicanos   Hombres
# 14                   Estados Unidos Mexicanos   Mujeres
#
#     Grupos quinquenales de edad_y  Población de 5 años y más migrante_y  \
# 0                           Total                           115693273.0
# 1                           Total                            56259714.0
# 2                           Total                            59433559.0
# 3                      05-09 años                            10764379.0
# 4                      05-09 años                             5453091.0
# 5                      05-09 años                             5311288.0
# 6                      10-14 años                            10943540.0
# 7                      10-14 años                             5554260.0
# 8                      10-14 años                             5389280.0
# 9                      15-19 años                            10806690.0
# 10                     15-19 años                             5462150.0
# 11                     15-19 años                             5344540.0
# 12                     20-24 años                            10422095.0
# 13                     20-24 años                             5165884.0
# 14                     20-24 años                             5256211.0
#
#    En otra entidad o país En otra entidad En los Estados Unidos de América  \
# 0                 4357929         3807844                           374155
# 1                 2270686         1917858                           260001
# 2                 2087243         1889986                           114154
# 3                  385509          353149                            20662
# 4                  194822          178194                            10544
# 5                  190687          174955                            10118
# 6                  334988          304784                            20721
# 7                  169188          154091                            10249
# 8                  165800          150693                            10472
# 9                  371644          345520                            15908
# 10                 180489          167602                             7639
# 11                 191155          177918                             8269
# 12                 553636          515834                            19721
# 13                 275628          254355                            11947
# 14                 278008          261479                             7774
#
#     En otro país No especificado_y
# 0         175930          259750.0
# 1          92827          202210.0
# 2          83103           57540.0
# 3          11698           13876.0
# 4           6084            7025.0
# 5           5614            6851.0
# 6           9483            8895.0
# 7           4848            4571.0
# 8           4635            4324.0
# 9          10216           10996.0
# 10          5248            6578.0
# 11          4968            4418.0
# 12         18081           26457.0
# 13          9326           20341.0
# 14          8755            6116.0
#
# [15 rows x 24 columns]
