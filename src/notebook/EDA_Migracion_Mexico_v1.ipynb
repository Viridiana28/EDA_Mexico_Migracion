# %% [markdown]
# # **Análisis exploratorio de Datos (EDA)**
#
# ## México y la imigración ¿Cuáles son sus causas?
#
# #### ¿Depende de la clase social la razón por la cuál los mexicanos migran? Hipótesis a contrastar: previsiblemente la clase social determina las razones por la cuales los mexicanos migran.

# %%
#Como primer paso voy a importar las librerias que necesitaré para poder realizar mi anális exploratorio de datos

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import plotly.express as px
import os.path

# %%
#En esta sección leeremos los archivos que necesitaremos para hacer tal análisis
'''En esta parte estoy teniendo problemas para poder acceder al archivo puesto que me marca un error diciendo que no encuentra el archivo, 
por lo tanto he revisado stack overflow y encontrado una solución que ha funcionado, la cual ha sido agregar la letra r al incio
'''


df_INEGI_Yr2020_07 = pd.read_excel(r"/Users/stefa/REPO_PRUEBA/EDA_Proyecto/src/data/cpv2020.xlsx",sheet_name="07",skiprows=[0,1,2,3,4,5])
df_INEGI_Yr2020_07


#El siguiente reto que me estoy encontrando es que el archivo en excel esta bloqueado, así que no puedo ajustar desde excel, y tendré que renombrar columnas
# Out:
#                                              Unnamed: 0 Unnamed: 1  \
# 0                                                   NaN        NaN
# 1                              Estados Unidos Mexicanos      Total
# 2                              Estados Unidos Mexicanos      Total
# 3                              Estados Unidos Mexicanos      Total
# 4                              Estados Unidos Mexicanos      Total
# ...                                                 ...        ...
# 1780                                       32 Zacatecas    Mujeres
# 1781                                       32 Zacatecas    Mujeres
# 1782                                       32 Zacatecas    Mujeres
# 1783                                                NaN        NaN
# 1784  1 Se refiere a la población que en marzo de 20...        NaN
#
#          Unnamed: 2  Unnamed: 3  Buscar trabajo  Cambio u oferta de trabajo  \
# 0               NaN         NaN             NaN                         NaN
# ...

# %%
'''En esta parte tuve un poco de problemas porque las filas con los títulos estaban concatenadas, así que parecía que necesitaba poner un salto de carro, al final, 
buscando, he visto que con el inplace funcionaba el cambio de nombre'''

df_INEGI_Yr2020_07.rename(columns ={"Unnamed: 0":"Entidad Federativa","Unnamed: 1":"Género","Unnamed: 2": "Grupos quinquenales de edad","Unnamed: 3" : "Población de 5 años y más migrante"},inplace=True)
df_INEGI_Yr2020_07
# Out:
#                                      Entidad Federativa   Género  \
# 0                                                   NaN      NaN
# 1                              Estados Unidos Mexicanos    Total
# 2                              Estados Unidos Mexicanos    Total
# 3                              Estados Unidos Mexicanos    Total
# 4                              Estados Unidos Mexicanos    Total
# ...                                                 ...      ...
# 1780                                       32 Zacatecas  Mujeres
# 1781                                       32 Zacatecas  Mujeres
# 1782                                       32 Zacatecas  Mujeres
# 1783                                                NaN      NaN
# 1784  1 Se refiere a la población que en marzo de 20...      NaN
#
#      Grupos quinquenales de edad  Población de 5 años y más migrante  \
# 0                            NaN                                 NaN
# ...

# %%
#Ahora estoy trayendo el Sheet número 5, el cual tiene los datos de lugares a los que los mexicanos han migrado

df_INEGI_Yr2020_5 = pd.read_excel(r"/Users/stefa/REPO_PRUEBA/EDA_Proyecto/src/data/cpv2020.xlsx",sheet_name="05",skiprows=[0,1,2,3,4,5],usecols="A:D,I:L")
df_INEGI_Yr2020_5
# Out:
#                     Unnamed: 0 Unnamed: 1     Unnamed: 2   Unnamed: 3  \
# 0                          NaN        NaN            NaN          NaN
# 1                          NaN        NaN            NaN          NaN
# 2     Estados Unidos Mexicanos      Total          Total  115693273.0
# 3     Estados Unidos Mexicanos      Total     05-09 años   10764379.0
# 4     Estados Unidos Mexicanos      Total     10-14 años   10943540.0
# ...                        ...        ...            ...          ...
# 1779              32 Zacatecas    Mujeres     65-69 años      23212.0
# 1780              32 Zacatecas    Mujeres     70-74 años      18020.0
# 1781              32 Zacatecas    Mujeres     75-79 años      13342.0
# 1782              32 Zacatecas    Mujeres     80-84 años       9417.0
# 1783              32 Zacatecas    Mujeres  85 años y más       9273.0
#
#      En otra entidad o país       Unnamed: 9  \
# 0                     Total  En otra entidad
# ...

# %%
#En este apartado he renombrado las columnas puesto que el Excel esta bloqueado y no se pueden modificar manualmente en el excel, por lo cual he tenido que utilizar las herramientas de pandas para nombrar las columnas

df_INEGI_Yr2020_5.rename(columns ={"Unnamed: 0":"Entidad Federativa de residencia actual","Unnamed: 1":"Género","Unnamed: 2": "Grupos quinquenales de edad","Unnamed: 3" : "Población de 5 años y más migrante","En otra entidad del país":"Total en otra entidad del país","Unnamed: 9":"En otra entidad","Unnamed: 10":"En los Estados Unidos de América","Unnamed: 11":"En otro país"},inplace=True)
df_INEGI_Yr2020_5
# Out:
#      Entidad Federativa de residencia actual   Género  \
# 0                                        NaN      NaN
# 1                                        NaN      NaN
# 2                   Estados Unidos Mexicanos    Total
# 3                   Estados Unidos Mexicanos    Total
# 4                   Estados Unidos Mexicanos    Total
# ...                                      ...      ...
# 1779                            32 Zacatecas  Mujeres
# 1780                            32 Zacatecas  Mujeres
# 1781                            32 Zacatecas  Mujeres
# 1782                            32 Zacatecas  Mujeres
# 1783                            32 Zacatecas  Mujeres
#
#      Grupos quinquenales de edad  Población de 5 años y más migrante  \
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                          Total                         115693273.0
# ...
